# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("seaice")
df.head()
# Out:
#         Date  Extent
# 0 1980-01-01  14.200
# 1 1980-01-03  14.302
# 2 1980-01-05  14.414
# 3 1980-01-07  14.518
# 4 1980-01-09  14.594

# %%
sns.lineplot(data=df, x="Date", y="Extent", hue=None, style=None, markers=False, dashes=True)
# Out:
# <Axes: xlabel='Date', ylabel='Extent'>
