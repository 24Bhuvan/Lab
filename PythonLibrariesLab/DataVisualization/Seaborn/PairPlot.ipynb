# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("penguins")

sns.pairplot(
    data=df,
    hue="species",
    palette="Set2",
    kind="scatter",
    diag_kind="kde"
)
